# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

matplotlib.rcParams['figure.dpi']= 300
matplotlib.rcParams['figure.figsize'] = [12, 8]

# %%
# this loads the local file unpack.py, force reloading it if necessary
import importlib
import sys
try:
    importlib.reload(sys.modules['unpack'])
    importlib.reload(sys.modules['plotutils'])
except KeyError:
    import unpack
    import plotutils

# set these as aliases this weird way to handle reloading
plot = plotutils.plot
select = plotutils.select
overlay_flushes = plotutils.overlay_flushes

# %%
core = unpack.unpack_data('bitcoin-core')
leveldb = unpack.unpack_data('core-leveldb')
# Out:
# Loading data from input file /home/evan/logs/bitcoin-core-1518996011.log
# Loading data from input file /home/evan/logs/core-leveldb-1518996042.log

# %%
#p = core['frames']['updatetip']
#prog = p['progress'] * 100
#list(prog)
#list(p.index.to_series())

c = core['frames']['updatetip']
l = leveldb['frames']['updatetip']

min_time = min(c.index[0], l.index[0])

c = c['progress']

l = l['progress']

cx = 0
lx = 0

times = []
cvals = []
lvals = []
while cx < len(c) or lx < len(l):
    if cx >= len(c):
        times.append(l.index[lx] - min_time)
        cvals.append(None)
        lvals.append(l[lx])
        lx += 1
        continue
    elif lx >= len(l):
        times.append(c.index[cx] - min_time)
        cvals.append(c[cx])
        lvals.append(None)
        cx += 1
        continue
        
    ct = c.index[cx] - min_time
    cv = c[cx]
    
    lt = l.index[lx] - min_time
    lv = l[lx]
    
    if ct == lt:
        times.append(ct)
        cvals.append(cv)
        cx += 1
        lvals.append(lv)
        lx += 1
    elif ct < lt:
        times.append(ct)
        cvals.append(cv)
        cx += 1
        lv = lvals[-1] if lvals else None
        lvals.append(lv)
    else:
        assert lt < ct
        times.append(lt)
        lvals.append(lv)
        lx += 1
        cv = cvals[-1] if cvals else None
        cvals.append(cv)

assert len(cvals) == len(lvals) == len(times)

times = np.array([t.to_timedelta64()/1e9 for t in times], dtype=np.float64)

# %%
c_flushes = list(core['frames']['flushes'].index - min_time)
l_flushes = list(leveldb['frames']['flushes'].index - min_time)

c_flushes = np.array([t.to_timedelta64()/1e9 for t in c_flushes], dtype=np.float64)
l_flushes = np.array([t.to_timedelta64()/1e9 for t in l_flushes], dtype=np.float64)

# %%
l_flushes
# Out:
# array([  761.,  1125.,  1551.,  1838.,  2195.,  2506.,  2776.,  3077.,
#         3484.,  3799.,  4131.,  4481.,  4846.,  5116.,  5224.,  5378.,
#         5530.,  5616.,  5716.,  6188.,  6919.,  7556.,  8302.,  9215.,
#        10053., 11005., 12002., 12876., 14265.])

# %%
df = pd.DataFrame({
    'master': cvals,
    'eklitzke': lvals,
    't': times,
}, index=times)

# %%
import datetime

def sec_formatter(t, _):
    dt = datetime.timedelta(seconds=t)
    return str(dt)

# %%
import matplotlib.ticker as mtick
from matplotlib import cm

#plot(df[['core', 'leveldb']])

#cmap = cm.get_cmap('Spectral')
cmap = cm.get_cmap('coolwarm')

fig = plt.figure()
ax = (df[['master', 'eklitzke']] * 100).plot(colormap=cmap)
ax.set_xlabel('Time')
ax.set_ylabel('Progress')
ax.set_title('Bitcoin IBD Progress')
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.xaxis.set_major_formatter(mtick.FuncFormatter(sec_formatter))

for x in c_flushes:
    plt.axvline(x=x, color=cmap(0.0), linestyle=':')

for x in l_flushes:
    plt.axvline(x=x, color=cmap(1.0), linestyle=':')
